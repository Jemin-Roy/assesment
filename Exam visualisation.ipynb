# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data=pd.read_csv('/content/diabetes_model.csv')

# %%
data
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              5       77             82             41       42  35.8
# 1              9      122             56              0        0  33.3
# 2              0      113             76              0        0  33.3
# 3              1      139             62             41      480  40.7
# 4             10      161             68             23      132  25.5
# ..           ...      ...            ...            ...      ...   ...
# 609            4      114             64              0        0  28.9
# 610            2      175             88              0        0  22.9
# 611            3      121             52              0        0  36.0
# 612            7      136             74             26      135  26.0
# 613            4      156             75              0        0  48.3
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.156   35        0
# ...

# %%
#  Pregnancies vs Glucose
data.plot(kind='scatter', x='Pregnancies', y='Glucose')
# Out:
# <Axes: xlabel='Pregnancies', ylabel='Glucose'>

# %%
data['Pregnancies'].plot(kind='hist',title='Pregnancies')
# Out:
# <Axes: title={'center': 'Pregnancies'}, ylabel='Frequency'>

# %%
plt.bar(data['Pregnancies'],data['DiabetesPedigreeFunction'])
plt.xlabel('Pregnancies')
plt.ylabel('DiabetesPedigreeFunction')
plt.title('Pregnancies & DiabetesPedigreeFunction')
plt.xticks(rotation=90)
plt.show()

# %%
plt.scatter(data['Pregnancies'],data['BloodPressure'])
plt.xlabel('Pregnancies')
plt.ylabel('BloodPressure')
plt.title('Pregnancies & BloodPressure')
plt.xticks(rotation=90)
plt.show()

# %%
import seaborn as sns

# %%
sns.pairplot(data,hue='Pregnancies')
plt.show()

# %%
sns.histplot(data['BMI'],bins=10,kde=True)
plt.title('histogram of BMI')
plt.xlabel('BMI')
plt.ylabel('frequency')
plt.show()

# %%
data2=data.head(10)
data2
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            5       77             82             41       42  35.8
# 1            9      122             56              0        0  33.3
# 2            0      113             76              0        0  33.3
# 3            1      139             62             41      480  40.7
# 4           10      161             68             23      132  25.5
# 5            2       68             70             32       66  25.0
# 6            2      108             80              0        0  27.0
# 7            2      122             52             43      158  36.2
# 8            3      120             70             30      135  42.9
# 9            3       61             82             28        0  34.4
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.156   35        0
# 1                     1.114   33        1
# 2                     0.278   23        1
# ...

# %%
plt.boxplot(data['SkinThickness'])
plt.show()
